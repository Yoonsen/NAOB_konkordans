# %%
import dhlab.text as dh

# %%
import pandas as pd

# %%
c = pd.read_csv('naob.csv')

# %%
crp = dh.Corpus_from_identifiers(list(c.urn.values))

# %%
crp.corpus
# Out:
#          dhlabid                                              title  \
# 0      100138308                               Aleksander den store
# 1      100462616                                Julian den frafalne
# 2      100000762      Keiser Hadrian : en kulturhistorisk Skildring
# 3      100571546                                  Keiser Konstantin
# 4      100522307         Lærebok i oldtidens historie for gymnasiet
# ...          ...                                                ...
# 10561  100445251  Therese : en kjærlighetshistorie fra virkeligh...
# 10562  100529945  Språkets mønstre : grammatiske begreper og met...
# 10563  100440998                              Mamma for første gang
# 10564  100043876  Medfødte misdannelser blant barn med fedre som...
# 10565  100048672                            Stygge hunders forening
#
#                                                  authors  \
# 0                                     Ræder , A. (Anton)
# ...

# %%
crp.corpus.to_excel('naob2.xlsx')
